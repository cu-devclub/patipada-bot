# %% [markdown]
# ## Retrieval

# %%
from llama_index.core import StorageContext,load_index_from_storage
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
import nest_asyncio
nest_asyncio.apply()

# %%
# %set_env OPENAI_API_KEY='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'
# Out:
# env: OPENAI_API_KEY='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'

# %%
embed_model = HuggingFaceEmbedding(model_name="intfloat/multilingual-e5-large",device='cpu')
load_index = load_index_from_storage(StorageContext.from_defaults(persist_dir='./localvecstore/'),embed_model=embed_model)

# %%
retrieval_engine = load_index.as_retriever(similarity_top_k = 10)
response = retrieval_engine.retrieve("ทางพ้นทุกข์")
print('-------------RAG-------------')

for i in response :
    print(i)
# Out:
# -------------RAG-------------
# Node ID: 1478
# Text: ทุกข์เกิดจากการสูญเสีย ทํายังไงถึงจะผ่านไปได้
# Score:  0.898
#
# Node ID: 915
# Text: ปรารถนาความพ้นทุกข์ในปัจจุบันนี้ได้ไหม
# Score:  0.890
#
# Node ID: 1450
# Text: ทิฐิในใจจะปลดปล่อยอย่างไรให้เกิดความสุขคะ
# Score:  0.877
#
# Node ID: 1508
# Text: ความหิวเป็นทุกข์หรือไม่
# Score:  0.877
#
# Node ID: 1617
# Text: การบวชปฏิบัติ
# Score:  0.877
#
# Node ID: 176
# Text: เรื่องเหตุและปัจจัย
# Score:  0.874
#
# Node ID: 357
# Text: ลูกกำลังจะไปถือศีล ขอธรรม ขอแนวทางพระอาจารย์ในการปฏิบัติ
# Score:  0.873
#
# Node ID: 1480
# Text: รักผู้หญิงคนหนึ่งให้ทุกอย่างกับเขา ทําไมต้องทุกข์
# Score:  0.873
#
# Node ID: 1426
# Text: ไม่รู้ว่าจะต้องปฏิบัติอย่างไรให้ไม่ต้องกลับมาเกิดอีก
# Score:  0.872
#
# Node ID: 963
# Text: บาปที่เกิดขึ้นในอดีตเราจะแก้บาปยังไง
# Score:  0.872
#
# Node ID: 764
# Text: พระอาจารย์อธิบายเพิ่มเติม
# Score:  0.871
#
# Node ID: 202
# Text: เห็นตอนเกิดนี่มันจะเหมือนง่ายกว่าไหมคะ
# Score:  0.871
#
# Node ID: 198
# Text: เราจะต่อสู้กับกามอารมณ์ที่มันหนักอย่างไรดีคะ
# Score:  0.870
#
# Node ID: 37
# Text: ทุกข์เกิดจากอะไรหรือครับ
# Score:  0.870
#
# Node ID: 819
# Text: ทําอย่างไร ให้ปล่อยวางสงบได้ เป็นคนไม่โกรธง่ายครับ
# Score:  0.870
#
# Node ID: 1345
# Text: การนั่งสมาธิสามารถแก้กรรมได้ไหม
# Score:  0.870
#
# Node ID: 635
# Text:
# หากตนเองเป็นคนคิดมากไม่ปล่อยวางจิตเป็นทุกข์ควรเริ่มปฏิบัติอย่างไรคะ
# Score:  0.870
#
# Node ID: 1615
# Text: ความหลงยินดีในความสุขในความเป็นอยู่ของชีวิต
# Score:  0.869
#
# Node ID: 670
# Text: การกระทำอาสวะให้สิ้นนั้นทำอย่างไร
# Score:  0.869
#
# Node ID: 588
# Text: ทําบุญอะไรไปสวรรค์ชั้นต่างต่าง
# Score:  0.869
#
# Node ID: 574
# Text: การที่ชอบมีคนมาทำให้ชอบ เป็นเพราะเราทำกรรมอะไรมา
# ควรแก้ไขอย่างไรดีครับ อารมณ์ไม่ตกหลุมรัก
# Score:  0.869
#
# Node ID: 870
# Text: ช่วยอธิบายคำว่าอิสระทางใจ
# Score:  0.869
#
# Node ID: 408
# Text: เวลาเดินจงกลม ก็รู้สึกงงเวียนหัวทํายังไงดี
# Score:  0.868
#
# Node ID: 730
# Text: วิธีปฏิบัติที่เราทําลายความคิดไม่ดีหรือความคิดอกุศลต้องทําอย่างไ
# รเจ้าคะ
# Score:  0.868
#
# Node ID: 453
# Text: เอาเป็นเครื่องระลึกถึงพระพุทธเจ้า
# Score:  0.868
#
# Node ID: 1341
# Text: ทำยังไงให้มีสติอยู่กับปัจจุบันไม่เอาอดีตมาทำร้ายตัวเอง
# Score:  0.868
#
# Node ID: 1669
# Text: ทำอย่างไรถึงจะได้ไปสู่พระนิพพาน หรือไปสู่พุทธภูมิ
# Score:  0.868
#
# Node ID: 1610
# Text: สภาพธรรม
# Score:  0.868
#
# Node ID: 1538
# Text: ในเวลาทํางานเราหนีซึ่งงานไปปฏิบัติธรรมอย่างนี้ได้บุญหรือไม่คะ
# Score:  0.867
#
# Node ID: 1203
# Text: การตัดภพตัดชาติว่าต้องตัดอย่างไร
# Score:  0.867
#
# Node ID: 689
# Text: การกราบไหว้เคารพสักการะบูชาที่ถูกต้อง
# Score:  0.867
#
# Node ID: 826
# Text: การมีชีวิตที่ขัดสนแล้วปฏิบัติธรรมด้วยความลำบาก
# Score:  0.866
#
# Node ID: 736
# Text: เมื่อเรามีอารมณ์ทุกข์จนดิ่งสุดและคิดทําร้ายตัวเอง
# จะดึงอารมณ์นั้นออกมาจากความคิดอย่างไรเจ้าค่ะ
# Score:  0.865
#
# Node ID: 41
# Text: ดูจิตเห็นจิตคิดขอรู้ ไม่คิดขอรู้แล้วนิ่งว่างทำยังไงต่อเจ้าคะ
# Score:  0.865
#
# Node ID: 1624
# Text: การทำกิจในสมุทัย (กิจที่ควรละ) ทำอย่างไรคะ
# Score:  0.865
#
# Node ID: 184
# Text: เรื่องการกำหนดรู้ รูปฌานและอรูปฌาน
# Score:  0.865
#
# Node ID: 1369
# Text: มีวิธีไหนที่เราสามารถตัดกรรมที่เกิดจากกรรมที่เราเคยทําในอดีตกับค
# นอื่นได้ไหม
# Score:  0.865
#
# Node ID: 1339
# Text: อยากจะแนะนําในเรื่องของการละ
# Score:  0.864
#
# Node ID: 1235
# Text: ขอวิธีตัดกรรมจากบุคคลที่เราไม่อยากพบเจออีกในภพต่อต่อไปมีวิธีปฏิบ
# ัติอย่างไรเจ้าค่ะ
# Score:  0.864
#
# Node ID: 1435
# Text:
# ทําอย่างไรจะรู้สึกวางเฉยกับทุกข์ที่เกิดกับเพื่อนในที่ทํางานได้ค่ะ
# Score:  0.863
#
# Node ID: 818
# Text: ทําอย่างไรกับการชนะกามครับ
# Score:  0.863
#
# Node ID: 1664
# Text: เจริญกายคตาสติเข้าถึงอรหัตผลเร็วที่สุด
# Score:  0.863
#
# Node ID: 315
# Text: ไม่มีสมาธิเลยทําอย่างไร
# Score:  0.863
#
# Node ID: 737
# Text:
# ทำอย่างไรไม่ให้จิตเราผูกติดกับความห่วงใยต่อบุคคลที่รักจนเป็นทุกข์
# Score:  0.863
#
# Node ID: 866
# Text: เราจะทําใจอย่างไรจะต้องกําหนดอย่างไรถ้าเรามีความทุกข์เข้ามารอบด้
# านเหมือนโดนกดดันบีบคั้นจากอะไรใดๆก็ตาม
# Score:  0.863
#
# Node ID: 67
# Text: เป็นกรรมที่ล่วงเกินบิดามารดาหรือไม่
# Score:  0.862
#
# Node ID: 57
# Text: ซึ่งมันช้าไปแล้วหรือไม่
# Score:  0.862
#
# Node ID: 1519
# Text: ปกติไล่ทันอารมณ์ความรู้สึกแล้วบอกทับอารมณ์ตามพระอาจารย์สอนเจ้าค่
# ะมาสองสามวันนี้มาเป็นความคิด
# Score:  0.862
#
# Node ID: 207
# Text: มีลูกไม่ปกติค่ะ
# Score:  0.862
#
# Node ID: 231
# Text: เป็นถึงพระพุทธเจ้ามีท้อด้วยเหรอคะ
# Score:  0.862
#
# Node ID: 358
# Text: หากทุกข์เพราะหัวหน้าลำเอียงต้องทำใจอย่างไร
# Score:  0.862
#
# Node ID: 517
# Text: การนั่งสมาธิได้บุญกว่าสิ่งอื่นใดใช่ไหม
# Score:  0.862
#
# Node ID: 1382
# Text: ตายแล้วฟื้นเนี่ย มันเป็นยังไง  ในมุมมองของพระพุทธศาสนา
# Score:  0.862
#
# Node ID: 1342
# Text: ทําไมคนที่ทำไม่ดีกับเราถึงมีความสุข
# แต่ทําไมคนที่ถูกกระทำกลับเป็นทุกข์
# Score:  0.862
#
# Node ID: 210
# Text: ขอโอกาสให้พระอาจารย์ช่วยอธิบายให้คนฟังอีกทีเพราะเห็นพระอาจารย์เข
# ียนว่าจิตแล้วก็มีตัววนรอบจิตแล้วก็ทางออกไปคือพระรัตนตรัย
# อันนี้แหละค่ะพระอาจารย์
# Score:  0.862
#
# Node ID: 59
# Text: การสวดมนต์ช่วยหรือไม่
# Score:  0.861
#
# Node ID: 444
# Text: ความไม่ปลอดโปร่งนี่ก็เป็นอารมณ์อย่างหนึ่ง
# Score:  0.861
#
# Node ID: 351
# Text: เราควรไปขอพรเซียนปะไหม
# Score:  0.861
#
# Node ID: 435
# Text: ตรงนี้เห็นยากใช่ไหมคะ
# Score:  0.861
#
# Node ID: 504
# Text: ถ้าเวรกรรมตามเราทัน ณ ตอนนี้เราควรทำอย่างไรดี
# Score:  0.861
#
# Node ID: 1290
# Text: ทําไมมันถึงเป็นอย่างนั้นคะพระอาจารย์
# Score:  0.861
#
# Node ID: 142
# Text: การนั่งสมาธิมีวิธีไหนบ้างครับ
# Score:  0.860
#
# Node ID: 1663
# Text: เพ่งโทษคนอื่นทางใจเป็นบาปไหมคะ
# Score:  0.860
#
# Node ID: 47
# Text: ความรู้สึกผิดที่ทรมานใจมันตั้งต้นมาจากไหนคะ
# Score:  0.860
#
# Node ID: 715
# Text: เก็บเงินได้หาเจ้าของไม่เจอ จะทําอย่างไรกับเงินนี้โดยไม่บาปเจ้าคะ
# Score:  0.860
#
# Node ID: 11
# Text:
# ถ้าเจ้าของทรัพย์ไม่ได้อยู่ในมณฑลให้คนอื่นถวายแทนจะได้บุญอย่างไรคะ
# Score:  0.860
#
# Node ID: 133
# Text: การอุทิศ โดยตั้งจิตแม้แต่ไม่ได้พนมมือไหว้ สามารถทําได้ไหมคะ
# Score:  0.860
#
# Node ID: 448
# Text: สิ่งที่เกิดขึ้น ก็แสดงว่าเป็นผล
# Score:  0.860
#
# Node ID: 1183
# Text: ทําอย่างไรให้นอนหลับง่าย ไม่ตื่นกลางดึก
# Score:  0.859
#
# Node ID: 1030
# Text: เมื่อเวลาเรามีสติที่ตั้งมั่นจะเป็นอย่างไร
# Score:  0.859
#
# Node ID: 1184
# Text: ขอโอกาสพระอาจารย์อธิบายคําว่า อยู่แบบไม่มีเพื่อนสอง
# Score:  0.859
#
# Node ID: 841
# Text: จะวางจิตอย่างไรไม่ให้เกิดความว่างที่กดข่มไว้ด้วยสมาธิ
# Score:  0.859
#
# Node ID: 1595
# Text: ถ้าเป็นคนผลัดวันประกันพรุ่งต้องฝึกปฏิบัติอย่างไรให้หายครับ
# Score:  0.859
#
# Node ID: 914
# Text: ในฐานะที่เป็นมนุษย์คนชุมชนที่ คือ ปฏิบัติธรรมไปด้วยแล้วก็คือยังไ
# ม่บรรลุหรือยังไม่สามารถที่จะก้าวข้ามการดับกามอราคะนี้
# จะมีวิถีชีวิตยังไงที่จะไม่ให้เกิดโทษ
# Score:  0.859
#
# Node ID: 1272
# Text: ก็คือเหมือนระลึกเพื่อจะดับแต่ดับผิดวิธีใช่ไหมคะพระอาจารย์
# Score:  0.859
#
# Node ID: 718
# Text: ช่องทางที่เข้าถึงสภาวะนิพพานต้องทําความเข้าใจทําอย่างไรครับ
# Score:  0.859
#
# Node ID: 596
# Text: เราต้องกําหนดรู้จนวันตาย
# Score:  0.859
#
# Node ID: 1096
# Text: ฟังธรรมแล้วชอบง่วง เป็นเพราะอะไรเจ้าคะ
# Score:  0.859
#
# Node ID: 232
# Text: กลัวการตกนรกค่ะทําอย่างไรดีคะ
# Score:  0.859
#
# Node ID: 1211
# Text: แล้วความสุขคืออะไร
# Score:  0.859
#
# Node ID: 403
# Text: ทําบุญยังไงให้ถูกบุญ
# แล้วทําอันไหนที่แบบเข้าใจว่าเป็นบุญแต่จริงๆไม่ใช่
# ลองยกตัวอย่างให้ทั้งทางที่ถูกและไม่ถูก
# Score:  0.859
#
# Node ID: 570
# Text: วิธีการเดินจงกรมต้องเริ่มอย่างไรคะ
# Score:  0.859
#
# Node ID: 181
# Text: การทำบุญให้คนที่เสียชีวิตหมดเป็นจำนวนเยอะเขาจะได้บุญไหม
# Score:  0.858
#
# Node ID: 524
# Text: กรรมของคนที่ไม่ดูแลรับผิดชอบบุตรจากสายเลือดตัวเองจะเป็นอย่างไร
# Score:  0.858
#
# Node ID: 166
# Text: เรานั่งสมาธิ แล้วฟังเทศน์ไปพร้อมกันได้ไหมคะ
# Score:  0.858
#
# Node ID: 31
# Text: ถ้าเราเจอผีเราต้องทำยังไงต่อไปค่ะพระอาจารย์
# Score:  0.858
#
# Node ID: 1389
# Text: ฝึกสมาธิแต่กลัวผี แต่ไม่เคยเห็นผีทําอย่างไร
# Score:  0.858
#
# Node ID: 414
# Text: ขอคําแนะนําการฝึกสติในชีวิตประจําวัน
# Score:  0.858
#
# Node ID: 427
# Text: ถ้าหากมีคนไปปรามาสเทวดาได้หรือไม่
# Score:  0.858
#
# Node ID: 893
# Text: งดการชมคลิปดาราสามวันเป็นการลงโทษตัวเอง ทําสําเร็จลุล่วงด้วยดี
# Score:  0.858
#
# Node ID: 28
# Text: เมื่อความเจ็บป่วยมาเยือนมีธรรมะข้อไหนที่พอจะช่วยได้คะ
# Score:  0.858
#
# Node ID: 1612
# Text: สถานที่ให้ประโยชน์อะไรกับการปฏิบัติบ้าง
# Score:  0.858
#
# Node ID: 409
# Text: อย่างคนที่ไม่เคยเดินจงกลมเลย
# ควรที่จะเอาจิตไปไว้ที่ไหนระหว่างที่เดินจงกลม
# Score:  0.858
#
# Node ID: 653
# Text: พระอาจารย์คะเราควรจะวางใจอย่างไร
# ถ้าเรามองเห็นสิ่งต่างต่างไม่เป็นไปอย่างใจเราควบคุมไม่ได้และเป็นทุกข์
# ความสุขเป็นของชั่วคราวความทุกข์แน่นอน
# Score:  0.858
#
# Node ID: 660
# Text: หากมีคนป่วยใกล้เสียชีวิต และเสียชีวิตภายในบ้านเรา
# เราควรทำอย่างไรเพื่อส่งดวงวิญญาณให้อยู่ในภพภูมิที่ดี
# Score:  0.858
#
# Node ID: 845
# Text: ถ้าฆ่าตัวตาย แล้วโลกหลังแห่งความตายมีอยู่จริงไหม
# Score:  0.858
#
# Node ID: 679
# Text: ญานทัศนะจะเกิดอย่างสมบูรณ์จนสิ้นอาสวะนั้นจะเกิดได้อย่างไร
# Score:  0.858
#
# Node ID: 451
# Text: เป็นของไม่ควรยินดีใช่ไหมคะ
# Score:  0.857
#
# Node ID: 424
# Text: เวลาเกิดความกลัวแล้วจิตมันตก ต้องทํายังไง
# Score:  0.857
#
# Node ID: 1045
# Text: ขั้นต่อไปของเวทนานุปัสสนา
# Score:  0.857
