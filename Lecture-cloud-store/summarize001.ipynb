# %% [markdown]
# #### กำหนด Service ที่เกี่ยวข้องกับ AI
#
# llm คือการกำหนดให้ใช้งาน LLM ตัวใดหรือผู้ให้บริการเจ้าใดสำหรับการรับ Prompt เพื่อให้ตอบคำถาม
#
# embed_model คือการกำหนดให้ใช้งาน Embedding ตัวใด สำหรับการแปลง Text ให้เป็น Vector
#
# prompt_helper คือตัวช่วยจิปาถะที่เกี่ยวข้องกับการใช้งาน LLM เช่น การทำให้ Prompt ที่ส่งไปยังผู้ให้บริการมีขนาดไม่เกินที่กำหนด (max_context)
#
# หรือ เมื่อ Prompt มีขนาดยาวเกินไปก็จะทำการ "ตัดข้อมูล" โดยอัตโนมัติ
#
# สำหรับ context_window ที่เรากำหนดขึ้นมานั้นมีขนาด 10,000 token ซึ่งการนับ Token โดย Default นั้น ใช้งาน Tiktoken หรือ OpenAI ในการนับ Token
#
# ทำให้ไม่สอดคล้องกับ SeaLLM-7b เนื่องจาก SeaLLM-7b นับ Token ต่างกับ OpenAI
#
# ส่งผลให้เมื่อใช้งาน context_window default จะทำให้ข้อมูลขาดหายไปบางช่วง
#
# DEFAULT context_window = 3900 #token

# %%
#ทำการ Import Library ที่จำเป็น
from llama_index.core import ServiceContext, StorageContext,VectorStoreIndex,Document
from llama_index.llms import openai_like
from llama_index.core import StorageContext, ListIndex
from llama_index.core.response_synthesizers import get_response_synthesizer
from llama_index.llms.openai import OpenAI
from llama_index.core.indices.prompt_helper import PromptHelper

# %%
import openai
openai.api_key = 'key'

# %%
#ทำการ Config API ที่ต้องการใช้
#OPENAI_KEY = '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'
FLOAT16_API_KEY = 'float16-56hBpTpGA5VYSs13Awe9U1FjGaTo5pNODx67cnI066EBP5rewr'
FLOAT16_CUSTOM_URL = 'https://api.float16.cloud/v1/llamaindex'

# %%
#ระบุ model ที่ต้องการใช้งาน
llm_model_name = "seallm-7b-v2"

#เชื่อมต่อกับ Float16
agent = openai_like.OpenAILike(
    api_key=FLOAT16_API_KEY,
    api_base=FLOAT16_CUSTOM_URL,
    model=llm_model_name,
    temperature=0.3,
    max_tokens=512,
)

# %%
service_context = ServiceContext.from_defaults(llm=agent,prompt_helper=PromptHelper(context_window=10000))
# Out:
# C:\Users\sukpi\AppData\Local\Temp\ipykernel_1540\1124538055.py:1: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(llm=agent,prompt_helper=PromptHelper(context_window=10000))

# %%
text = "A1 : อาการที่ถูกตีไม่โกรธแต่ไปรับรู้ความรู้สึกของผู้ตีแล้วเกิดความโกรธขึ้นเป็นระบบของขันธ์คือทุกข์กับสมุทัยที่ทําหน้าที่เกิดร่วม มองเห็นทุกข์กับสุโขทัยไหมในเหตุการณ์ที่เล่ามานี้ ทุกข์คือตัวเขา สมุทัยคือการไม่รู้แล้วไปรับอารมณ์ อันนี้สมุทัยเก่าไม่ใช่สมุทัยใหม่แล้วมันมีตัวไปรู้อีก ตัวรู้ตัวนี้เป็นอีกตัวหนึ่ง ซึ่งมีตัวตนเข้าไปรู้อีกตัวหนึ่งแสดงว่าเขาสร้างคุณสมบัติของสิ่งนี้มา สิ่งนี้เลยจึงเกิดขึ้นมาเพื่อทําหน้าที่ในการรู้คุณสมบัติตัวนี้ถูกมันถูกสร้างขึ้นแล้วมันจะไม่หายไปไหนมันจะติดตามมากับจิตเพื่อทําหน้าที่กําหนดรู้สิ่งที่ตัวเรากําลังเป็นในปัจจุบันนี้ได้เหมือนกัน ดังนั้นสิ่งที่เราปฏิบัติเราฝึกกันอยู่เนี้ยมันไม่ได้หายไปไหนมันกําลังจะสะสมเป็นก้อนความรู้และมีก้อนก้อนความรู้เป็นคุณสมบัติของใจของเราได้เมื่อไหร่เมื่อนั้นเราไปเจอสภาพการณ์ใดก็ตามเราจะเป็นแบบเดียวกันก็คือจะมีตัวรู้เข้าไปกําหนดได้เอง ก็จะรู้อะไรรู้ทุกข์กับสมุทัย รู้ว่าทุกข์ คือร่างกาย คือขันธ์ คือตัวของเขาที่เขาเป็นอยู่ในภาวะปัจจุบันที่ถูกตี แล้วก็คือไปรับรู้อารมณ์ของผู้ตีแล้วเกิดมาเป็นความโกรธ โกรธที่ว่าทําให้ท่านโกรธเรา ทําให้ท่านโมโห เราโกรธที่เราทําไม่ดี ที่ท่านมาทําเราเข้าใจไหมมันจะเป็นอย่างนี้แหละ นี่คือระบบของการรู้ขันธ์ 5 ที่มีเกิดร่วมเป็นสมุทัยเก่าทั้งนั้นเลย นี่คือระบบที่มันต้องเป็น เพราะฉะนั้นพระองค์จึงบอกว่าทุกข์สมุทัยเป็นสิ่งที่แยกจากกันไม่ได้ทุกข์อยู่ที่ไหน สมุทัยจะอยู่ที่นั่น แล้วเมื่อทุกข์สมุทัยอยู่ด้วยกันการดับไฟก็คือการดับไปของทุกข์กับสมุทัยนั่นแหละ นิโรจน์ที่แท้จริง คือการดับไปของสมุทัย เพราะเมื่อสมุทัยดับทุกข์จะดับ พระอาจารย์จึงมาแยกเป็นสมุทัย ต่อสมุทัยใหม่ซึ่งไม่มีใครอธิบายหรอกเรื่องพวกนี้ แต่มันมีการวิธีการอธิบายเพื่อให้เราได้เข้าใจว่าควรจะละตัวไหนไม่ใช่ไปละตัวที่กําลังเกิดขึ้นไม่งั้นเราละผิดกัน แล้วเราถูกสอนให้ละตัวตัณหาที่มันเกิดร่วมกับทุกข์ซึ่งเป็นสมุทัยเก่าอยู่ตลอดเวลาเมื่อเราถูกสอนให้เป็นละหรือไปดับสมุทัยเก่าคือตัวตัณหาตลอดเวลานั่นคือเราดับผิดที่ เพราะว่าตัวตัณหาที่เกิดร่วมกับความทุกข์ทําให้ทุกข์เกิดขึ้นจริงต้องยอมรับว่าตอนนี้ทุกข์เกิดจากตัณหาถูกต้องไม่ผิดมันไม่ผิด ผิดก็คือเราไม่รู้กระบวนการนี้มันจึงมีอวิชชาสร้างตัณหาใหม่จากตัณหาเดิม นี่แหละคือจะตัวดึงเราลงสู่ภพ นี่คือที่พระอาจารย์บอกคือเงื่อนต่อของภพชาติมันอยู่ตรงนี้ ในระดับภพชาติดับอยู่ตรงนี้คือการรู้ทุกข์รู้สมุทัย ฉะนั้นทุกข์ต้องมีให้รู้สมุทัยก็ต้องมีให้รู้ ทุกข์ต้องมีให้เห็นสมุทัยก็ต้องมีให้เห็นคําว่ามีให้เห็นคือไม่ต้องไปดับมันให้เห็นมัน เห็นด้วยอํานาจของสมาธิและเมื่อเห็นแล้วก็จะเห็นการสุดกระบวนความของมันที่มันเกิดแล้วก็ดับไปคือนิโรธก็จะเห็นสัจจะทั้ง 3 ผู้เห็นอยู่อย่างนี้ก็เป็นมรรคสัจจะสัจจะก็ครบ 4 อริยสัจ 4 จะปริวัตรคือเวียนรอบอยู่ในใจเราอยู่อย่างนี้ทุกคราวที่เราฝึกปฏิบัติอย่างเข้าใจต่อเรื่องแต่ละเรื่อง แต่ละเรื่องอย่างชัดเจน เราก็จะเห็นภาวะของทุกข์สมุทัยเกิดดับ เกิดดับ จึงมีบทบาลีที่ทําให้เราได้เข้าใจด้านญาณทัศนะคือความรู้ความเห็นตามความเป็นจริงว่า ยังกิญจิ สะมุทะยะธัมมัง สัพพันตัง นิโรธะธัมมันติ ยังกิญจิ สิ่งใดสิ่งหนึ่ง สะมุทะยะธัมมัง เกิดขึ้นเป็นธรรมดา พระพทุธองค์ตรัสว่าสิ่งใดสิ่งหนึ่งเกิดขึ้นเป็นธรรมดารู้ไหมก็คือสิ่งไหน บาลีทําไมแค่ใช้คําว่ายังกิญจิ คือสิ่งใดสิ่งหนึ่งแต่มันทําไมไม่ระบุว่าสิ่งไหน รู้ไหมอะไรเกิดเป็นธรรมดา นี่แหละคําสอนพุทธเจ้าจะเป็นอย่างนี้ ถามว่าเป็นคําสอนที่ผิดไหม ไม่ผิดถูกต้องแต่ความเข้าใจของเราไม่ได้เข้าใจตรงความถูกต้องแล้วทําไมพระองค์ไม่ระบุเลยว่าคือสิ่งไหนกันแน่ที่เกิดที่ดับอยู่ สิ่งใดสิ่งหนึ่งเกิดขึ้นเป็นธรรมดาสิ่งนั้นย่อมดับเป็นธรรมดา ทุกอย่างมันก็ใช่แต่เราไปแก้ปัญหาในทุก ๆ อย่างไม่ได้ ปัญหาที่เราจะต้องแก้คืออยู่ตรงจุดไหนที่เราต้องไปเห็นว่ามันเกิดขึ้นเป็นธรรมดา บทบาลีมันอธิบายเรื่องราวนี้ไว้หมดแล้วถ้าเราเข้าใจบทบาลี ถ้าเราไม่เข้าใจบทบาลีเราจะไม่รู้หรอกเราก็จะงงอยู่อย่างนี้แหละสิ่งใดสิ่งหนึ่งมันคือสิ่งไหน หรือแม้แต่คําว่า เย ธัมมา เหตุปัปพวา ธรรมทั้งหลายเหล่าใดเกิดแต่เหตุ แล้วมันธรรมเหล่าไหนล่ะ มีแต่บอกว่าธรรมเหล่าใดเกิดอุบัติเหตุ มันเป็นธรรมเหล่าไหนล่ะ แต่จริง ๆ บทบาลีมันอธิบายไว้เรียบร้อยแล้วมันคืออะไร มันคือธรรมเหล่าไหน ฉะนั้นในบทนี้เหมือนกัน ยังกิญจิ สะมุทะยะธัมมัง สัพพันตัง นิโรธะธัมมันติ สิ่งใดสิ่งหนึ่งเกิดขึ้นเป็นธรรมดา เกิดเขาบอกแล้วสะมุทะยะ สมุทัย พอสมุทัยเกิดทุกข์จึงเกิดใช่ไหม แล้วมันเกิดธรรมดาคือมันเป็นธรรม ธรรมที่เกิดธรรมดาเพราะว่ามันเป็นสมุทัยเก่าที่เกิดร่วมพร้อมกับขันธ์อยู่แล้วมันเป็นของเก่ามันก็เลยเกิดเป็นธรรมดาเพราะมันมีของเก่าติดมาไม่ให้มันเกิดไม่ได้มันต้องเกิด ไทยไม่เกิดก็สิ้นอาสวะกันหมดแล้ว แล้วเราไม่ได้อยู่ในฐานะผู้สิ้นอาสวะเราอยู่ในฐานะปุถุชนก็ยอมรับว่าเราเป็นปุถุชนอย่าไปสร้างความเป็นอริยะในความเป็นปุถุชน คิดว่าเราต้องไม่มีตัณหาตัณหาต้องไม่มีในเรา เราจะต้องดับตัณหาให้ได้ ยอมรับตัณหาที่เกิดกับตัวเองไม่ได้เพราะมองว่าตัณหาเป็นสิ่งเลวร้าย เราอยู่ในนิสัยปุถุชนที่มีตัณหาประกอบเราไว้อยู่แล้วก็ต้องยอมรับมันตามความเป็นจริง การไปดับตัณหาคือการไม่ยอมรับความจริงที่เกิดขึ้นกับตนเองว่าเราเป็นปุถุชนเข้าใจว่าเราต้องดี เราจะต้องปฏิเสธความไม่ดี อันนั้นคือการปฏิบัติผิด หลักการของพระพุทธเจ้าก็คือ สะมุทะยะธัมมัง เห็นมันเกิดเป็นธรรมดา สมุทัยเกิดเป็นธรรมดา มีสมุทัยก็ต้องมีทุกข์เป็นธรรมดา ก็ถูกต้องก็ยอมรับทุกข์ยอมรับสมุทัยก็รู้รู้ว่ามันเกิดเป็นธรรมดา สัพพันตัง นิโรธะธัมมันติ เมื่อมันเกิดเป็นธรรมดา จะเกิดมากี่ครั้ง กี่หน ทั้งหมดเหล่านั้น นิโลทะ นิโรจน์ใช่ไหม บทนี้จะกล่าวถึงสมุทัยกับนิโรธ นิโรธะ คือการดับเพราะว่าการเกิด ใช้คําว่า อุปนะ ก็ได้แต่ทําไมไม่ใช้คําว่า อุปนะ อุปนะ แปลว่าการเกิดแต่ทําไมพระองค์ไม่พูดคําว่าอุปณะในบทนี้ แต่ทําไมบอกว่า สะมุทะยะ เพื่อบ่งบอกให้ทราบว่าสิ่งที่เกิดนี้ คือตัณหาเกิด เมื่อตัณหาเกิดทุกข์จึงเกิด อย่างอื่นใช้คําว่าอุปนะได้ เช่น การเกิดอุปนะ หรืออุปติ การเกิดในภพชื่อว่าอุปติ แต่การเกิดที่พอบอกว่าสิ่งในสิ่งหนึ่งเกิดขึ้นไม่ธรรมดาก็คือสมุทัยระบุถึงสมุทัย ในจิตเราสมุทัยเกิดทุกข์ก็เกิด เมื่อเกิดแล้วก็บอกชี้ชัดได้ว่ามันเกิดมาเท่าไรมันก็ดับไปเท่านั้นก็คือนิโรจน์ก็ดับไปเป็นธรรมดาสิ่งเหล่านี้จะเป็นญาณทัศนะรองรับจิตของพระโสดาบันเท่านั้นปุถุชนจะไม่มี ปุถุชนจึงต้องมาฝึกที่จะรู้ที่จะเห็น พระพุทธองค์จึงตรัสว่าพระโสดาบันเป็นผู้มีทิฐิสัมปันโน คือความเห็นสมบูรณ์คือเห็นอย่างนี้แหละแบบสมบูรณ์ คือเห็นโดยไม่ต้องกําหนดรู้คือเห็นเองโดยธรรมชาติของจิตเป็นอัธยาศัยในภายใน แต่ปุถุชนต้องฝึกที่จะกําหนดรู้ว่าทุกข์เป็นแบบนี้ สมุทัยเป็นแบบนี้ นี่โลกเป็นแบบนี้ แล้วเขาไปเห็นว่าทุกข์เกิดและยอมรับ สมุทัยเกิดและรู้ รู้เพื่อที่จะไม่ให้มีสมุทัยใหม่เกิดขึ้นก็จะละเอง แล้วเมื่อสมุทัยนั้นเกิดจนเต็มที่ของมันแล้วก็ดับไปก็เป็นนิโรธรู้อย่างนี้แหละ คือมรรค\nA2 : เมื่อเราเห็นแล้วว่ามันดับไปได้ด้วยตัวมันเอง นี่คือการเรียนรู้ที่ทําให้รู้ว่าก่อนที่ความโกรธจะเกิดขึ้นในใจเรา ความโกรธไม่มีในขณะนั้น เมื่อมันเกิดขึ้นแล้วมันจึงมีอยู่แล้วตั้งอยู่เมื่อตั้งอยู่แล้วเราเห็นการเกิดขึ้นจนสิ้นกระบวนความและดับไปได้และเป็นการดับไปด้วยตัวของความโกรธเอง ไม่มีใครไปดับมัน มันก็ดับ หลักการก็คือเราจะได้ความรู้จากการเห็นอาการแห่งความโกรธโดยที่ไม่ต้องไปดักมัน การที่เราไม่ดับมันนี่แหละคือการเห็นตามความเป็นจริงการเห็นตามความเป็นจริงจะเกิดฌานทัศนะขึ้นมา แล้วคราวครั้งต่อไปเราจะรับมือกับความโกรธได้สั้นลง ๆ สั้นลง ๆ จนถึงการรู้เท่าทันจนเกิดปั๊บดับปุ๊บได้ มันก็จะค่อย ๆ ฝึกอย่างนี้ขึ้นมาถูกต้องแล้ว\nA3 : คือพุทโธมีนโถนี่เป็นพื้นฐานที่ จะแก้ไข คือปรับจิตของเราให้อยู่ในกุศลมหากุศลแล้วนะ ถ้าลืมนี่มันเหมือนกับว่า หมอให้ยากันลืม แต่ลืมกินยากันลืม มันก็แก้ไปได้อย่าง เงี้ย ก็ก็ลืมกินยารักษาโรคไม่ได้ เอา งี้ ก็แล้วกัน สวดรัตนปริตร สวดอาราธนาปริตรแล้วเวลาทําบุญ ก็ให้ทําบุญ อุทิศให้กับ อะไรก็ได้ หรือผู้ที่ทําให้เราเป็นคนขี้ลืมมันอาจจะมีอะไรบางอย่างที่ทําให้เราขี้ลืม อะ คือมัน มันมีการตัดสัญญาณการระลึกรู้ของเราอยู่ อ่า นายเวรบางจําพวกหรือดวงจิตดวงวิญญาณที่ต้องการก่อกวนเรา สวด แล้วทําบุญอุทิศให้กับบุคคลให้กับผู้ที่ทําให้เราขี้ลืมนะ ลองทําอย่าง งี้ ดู"

# %%
text = "ความรักทางโลกมันก็ต้องรักเพราะโลกนี้มันต้องอาศัยความรักที่มันมีอยู่แล้วในกมลสันดานคือมันมาอยู่ภายในหัวใจในตัวคนอยู่แล้วเป็นเรื่องปกติ ความรักอันนี้เป็นความรักโดยความรู้สึกเป็นความรักโดยสัญชาตญาณเป็นความรักโดยเป็นขันธ์สันดาน ความรักเกิดจากสองสาเหตุอยู่ด้วยกันแต่ปางก่อนและก็เกื้อกูลกันในปัจจุบัน สองประการนั่นคือความรักและคนๆหนึ่งที่ไม่เคยอยู่ร่วมกันแต่ปางก่อนกับคนอื่นมาเป็นไม่มีหมายถึงว่าคนทุกคนเคยอยู่ร่วมกันมาทั้งหมด ไม่ว่าจะเป็นการอยู่ร่วมกันด้วยความรักความโกรธความเกลียดความเคียดแค้นชิงชัง มันก็เคยอยู่ร่วมกันมากันทั้งนั้นเพราะฉะนั้นความรักทางโลกเป็นความรักตามการเคยอยู่ร่วมกันมาคือความผูกพันความเชื่อมโยงกันความเกี่ยวโยงกันความรักทั้งโลกยังเป็นความรักที่ผูกพันกันเกาะเกี่ยวกันพัวพันกันเชื่อมสัมพันธ์กันและสิ่งเหล่านี้ยังเป็นความรักที่นําไปสู่โทษอีกต่างๆมากๆ เช่นเมื่อกําลังแห่งความรักมีต่อกันอย่างเต็มที่ก็รักกันอย่างกลมเกลียวแต่เมื่อกําลังแห่งความรักนั้นเสื่อมสลายไปก็รังเกียจกันอย่างเต็มที่เหมือนกันคือโกรธกันอย่างเต็มที่เหมือนกันเกลียดกันอย่างเต็มที่เหมือนกันบางคนรักกันสุดหัวใจเวลาเกลียดก็เกลียดคนที่เรารักเคยเคยรักแบบสุดหัวใจมาก็เกลียดแบบสุดหัวใจเหมือนกันเข้ากระดูกดำเหมือนกัน เราก็เห็นข่าวตามที่ต่างๆใช่ไหม ที่ว่ารักแล้วไม่สมหวังก็ผูกคอตายบ้างฆ่ากันตายบ้าง อะไรประเภทนี้ก็คนที่เรารักไปฆ่ากันได้ยังไงหรือฆ่าตัวเองเพราะผิดหวังจากคนที่เรารัก คือมันเป็นโทษอยู่แล้วที่ปรากฏให้เราได้เห็นได้ชัด ความรักทางโลกจึงเป็นความรักที่นํามาซึ่งโทษมากมาย วัยรุ่นจึงได้รับโทษจากการที่รักโดยการขาดสติรักไปตามความรู้สึกรักโดยใช้ความรู้สึกเป็นที่ตั้ง รักโดยการใช้ความไว้วางใจกันจนขาดสติยับยั้งถล้ำลึกเป็นความรักถล้ำลงไปสู่ความอะไร ความโมหะ ความหลง ลุ่มหลงอยู่กับความรัก หลงกันจนหาทางออกไม่ได้ หมกมุ่นอยู่ในนั้น หมกมุ่นอยู่ในความรักนั้น วัยรุ่นมักจะเป็นอย่างงั้นพอเศร้าอกเสียใจก็เสียใจปานจะขาดใจตาย พอความเสียใจสั่งคลายลงไปก็เริ่มได้มีสติขึ้นมาอีกสักระยะหนึ่ง ต่อไปจะมีความรักเริ่มระหวาดระแวงในความรักก็มีมันก็หลายหลายอย่างเรื่องความรักทางโลก แต่ความรักของทางธรรมความรักของทางธรรมแทบจะเป็นความรักแบบทางธรรมได้ความรักนั้นจะต้องเริ่มจากความเป็นพระโสดาบันก่อนจนถึงพระอรหันต์พระโสดาบันจะมีความรักแบบทางธรรมไปจนถึงความเป็นพระอรหันต์จะมีความรักแบบทางธรรม คําว่ารักแบบทางธรรมหมายถึงว่ารักโดยที่ไม่มีความเกลียดแม้แต่คนที่เกลียดก็ยังรักคือหมายความว่าความรักของพระพุทธเจ้าไม่ใช่ว่าจะรักไปเสียทั้งหมด แต่มีความรักให้หมดทุกคน พุทธเจ้ารักพระเทวทัต พระเทวทัตแสดงสิ่งที่เป็นน่ารังเกียจ พระองค์ก็รังเกียจในสิ่งที่พระเทวทัตทำแต่พระองค์ไม่เคยหมดความรักในพระเทวทัตแต่รังเกียจในสิ่งที่เทวทัตทำในกรรมอกุศลกรรมบางอย่างรังเกียจจนไม่ให้เข้าหมู่ให้แยกออกไปจากหมู่ไม่ให้ร่วมอุโบสถไม่ให้ร่วมอยู่ในสังคมหรือสังคมสงฆ์อันเดียวกันฟังปฏิโมกข์ด้วยกันไม่ได้ นั่นคือรังเกียจในการกระทำแต่พระองค์ไม่เคยหมดความรักในพระเทวทัต รักได้แม้กระทั่งศัตรูเป็นความลับของพระอริยเจ้าคือความรักทางธรรม รักโดยที่ไม่เกลียด คือมันรักคนทั้งโลกได้หมด รักแม้กระทั่งอิสลามก็ได้ รักแม้กระทั่งคนที่เป็นคริสต์ก็ได้ศาสนาพราหมณ์ก็ได้รักแต่ไม่ใช่เป็นรวมหมายถึงว่าข้อประพฤติที่เป็นโทษอันนั้นเราจะยินดีไปด้วยเราไม่ได้ยินดีเป็นความรักแบบมีปัญญาความรักที่ไม่เคยรังเกียจใครเลยเป็นความรักที่ไม่มีโทษแม้บุคคลผู้นั้นจะกระทำสิ่งที่น่ารังเกียจและจะทำสิ่งที่เป็นไปเพื่อความขัดแย้งในใจของพุทธองค์ พระองค์ก็ไม่เคยหมดรักในคนคนนั้นยังมีความรักกับคนๆนั้นอยู่เหมือนเดิมมันเป็นเรื่องแปลกอย่างหนึ่งจะเกิดอยู่ในจิตของพระอริยเจ้าเท่านั้นจะรู้ พูดได้อย่าง เงี้ย มันพูดไปมากกว่านี้ก็ไม่ได้ ให้ลึกซึ้งกว่านี้ก็พูดไม่เป็นเรื่องความรักแต่รู้สึกซึ้งอยู่ในตนเองตรงที่ว่าทําไมจิตเราถึงสามารถรักคนทั้งโลกได้ แม่รักลูกอย่างไรใจของพระอริยเจ้าก็รักคนทั้งโลกแบบนั้นแบบเดียวกันเลยที่แม่รักลูก แม่รักลูกได้เฉพาะลูกของตน รักลูกคนอื่นเหมือนกับลูกของตนเองไหม ไม่แต่พระอริยเจ้ารักคนอื่นเท่ากันเหมือนกับแม่ที่รักลูกนั้นมันต่างกันต่างกันตรงนี้อันนี้คือพระอริยเจ้าแต่ปุถุชนน่ะไม่ต้องพูดถึงพอใจก็รัก ไม่พอใจก็เกลียด ถูกใจก็รัก ไม่ถูกใจก็เกลียด เพราะมนุษย์มันมีทั้งคุณทั้งโทษ เวลาดีต่อกันก็ให้คุณกันแต่เวลาร้ายก็โทษกัน เป็นเพราะเป็นเพราะนั่นเป็นเพราะนี้เป็นเพราะคนนั้นโทษกันไปหมดนั่นแหละนี่คือมนุษย์"

# %%
text1 = "เราไม่ต้องไปบอกให้หายห่วง ให้เรียนรู้ ให้เรียนรู้จิต จิตที่มันผูกติดอยู่ก็คือจิต ๆ หนึ่งอารมณ์หนึ่งความรู้สึกหนึ่งที่มันเกิดขึ้น มันแสดงภาวการณ์ของการยึดโยงเราระหว่างลูกหลานครอบครัวทั้งหลายเหล่านี้เกิดการยึดโยงกันอย่างนี้ ตัดกันไม่ขาด ตัดกันยากมากเลยสิ่งเหล่านี้ หลักการก็คือเรียนรู้ความเกิดและความดับของอารมณ์นี้ให้เข้าไปทักอารมณ์ ความห่วงกําลังเกิดขึ้นกับจิต จิตกําลังมีความห่วง ความห่วงกําลังปรุงแต่งจิต จิตกําลังถูกความห่วงปรุงแต่งอยู่ ให้รู้อย่างนี้ พอเข้าไปรู้มากขึ้น ๆ อยู่เรื่อย ๆ ทั้งตอนเกิดตอนดับทุกครั้งที่เรารู้ เรารู้ทันเมื่อไหร่จะเป็นสติเมื่อนั้น เป็นสติเมื่อไหร่ สติก็จะรับรู้อาการ อารมณ์ ความรู้สึกห่วงไว้อยู่เสมอ การปฏิบัติไม่ได้เป็นการปฏิบัติเพื่อให้อาการห่วงหายไป เราต้องห่วงเราต้องกังวลเป็นเรื่องปกติเป็นเรื่องธรรมดามีสายใยกันอยู่ แต่เราจะรับรู้อารมณ์นั้นด้วยสติ อย่างน้อยระลึกถึงพุทโธ เม นาโถ ระลึกถึงพระรัตนตรัย ก็ยังตัดได้ใช่ไหม แต่นั่นไม่ใช่การตัด เป็นแค่รักษาใจเราไม่ให้ไปอยู่กับความวิตกในฝั่งของความห่วงแต่มันก็มาเกิดขึ้นมาอีกครั้งอยู่ดี วิธีการตัดจริง ๆ คือการเข้าไปเรียนรู้หรือทักอารมณ์ ความห่วงกําลังเกิดขึ้นกับจิต จิตกําลังมีความห่วง ความห่วงกําลังเกิดอยู่ในจิต จิตกําลังถูกความห่วงปรุงแต่ง ความห่วงกําลังปรุงแต่งจิต เข้าไปทักย้ำ ๆ ซ้ำ ๆ แล้วก็เข้าไปรับรู้อารมณ์ด้วยสติ การไปรับรู้อารมณ์ด้วยสติ ไม่จำเป็นต้องให้หายไป ก็ให้รับรู้ด้วยสติ ไม่จำเป็นต้องไปตัด สติที่เพียงพอต่อการรู้แล้วจะตัดของมันเอง ในการตัดไม่ใช่หน้าที่ของเรา เพราะเราปฏิบัติอยู่บนหลักการของอนัตตาคือไม่มีตัวตนของผู้ปฏิบัติ แต่มีการปฏิบัติอะไรเป็นตัวปฏิบัติสติ ปฏิบัติใช่ไหม สมาธิเป็นตัวปฏิบัติ ปัญญาเป็นตัวปฏิบัติ อริยมรรคเป็นตัวปฏิบัติ ปฏิบัติต่อสิ่งนั้น ๆ แต่ไม่มีเรา ฉะนั้นเราจึงมีหน้าที่ของเราคือสร้างสติ สร้างสมาธิ สร้างปัญญา สร้างอริยมรรคขึ้นมาถ้าเราสร้างมาแล้ว สิ่งเหล่านี้จะเข้าไปสู่การตัดการละ การคลาย การวาง ถ้าเรียนรู้เพียงพอแล้วจะตัดเอง จะละเอง จะคลายออกเอง จะวางออกเอง แต่ถ้าสติยังไม่พอ ก็ต้องฝึก ฝึกโดยการเข้าไปรู้ การเรียนรู้จะเป็นตัวสร้างสติ เวลาขณะที่เราเรียนรู้อารมณ์ที่เกิดขึ้นแต่ละครั้ง เรียกว่าวิชชา วิชชาคือการเรียนรู้ วิชชาคือการเรียนรู้ ปัญญาคือการรอบรู้ สติคือการระลึกรู้ ญาณคือการหยั่งรู้ตามความเป็นจริง จะต้องพัฒนาไปถึงขั้นญาณ สิ่งเหล่านี้ยังจะเกิดขึ้นเมื่อถูกรู้ ถูกปฏิบัติ ตั้งแต่สติไปถึงวิชชา เรียนรู้ก่อให้เกิดสติ สติก่อให้เกิดสมาธิ สมาธิก่อให้เกิดปัญญา ปัญญาก่อให้เกิดญาณ ญาณไปสู่อริยมรรคตามลำดับอย่างนี้ พัฒนาตัวเองไปอย่างนี้เรื่อย ๆ พอเข้าถึงอริยมรรคแล้ว แบบมรรคญาณอีกครั้ง ยังมีญาณประกอบอยู่ จะมีการตัดเอง จังหวะตัดเอง เวลาลูกจะไปไหน ครอบครัวจะไปไหน ก็บอกไปไหนก็ไปเถอะ ไม่ได้กังวลแล้วทีนี้ ไปไหนก็ไปเลยอย่างนี้ เราอยู่กับความวิเวกได้หายห่วง"

# %%
text2 = "หรอ มีกามสองอย่างที่เรียกว่าสังโยชน์ของบุคคลผู้เป็นอนาคามีจําเป็นต้องละก็คือรูปราคะกับอรูปราคะ ถ้าจะกล่าวถึงความเป็น กล่าวได้ไหม เป็นอย่างนี้ ความยินดีพอใจรักใคร่ในอย่างใดอย่างหนึ่งอย่างเช่นในรูป ในเสียง ในกลิ่น ในรส ในภาพอย่างนี้ ความยินดีพอใจ จนกระทั่งไม่สามารถผละออกไป คือไม่สามารถวางใจ ไม่สามารถผละออกไปคิดใคร่ครวญอยู่ตลอดเวลา แสวงหาอยู่ตลอดเวลาอย่างนี้ คล้อยไปตามอยู่ตลอดเวลา เขาเรียกว่า ตรงนี้จึงจัดอยู่ในความเป็นนิวรณ์ ถามว่าทําไมพอมีการมาฉันทะแล้วไม่สามารถประพฤติปฏิบัติธรรมไปได้ พอจะกล่าวก็ต้องละนิวรณ์ก่อนใช่ไหม นิวรณ์ธรรมนั้นต้องเอาออกไปก่อน ทําให้จิตนี้อ่อนควรแก่การงาน เพราะมันจะดึงจิตนั้นให้ไปหากามอยู่เรื่อยๆ ถามว่าการคิดการใคร่ครวญมันจะคิดยังไงตอนนั้นก็คิดว่าตรงไหนจะเสพเสวยอะไรยังไงมีรูปมีเสียงมีกลิ่นมีรสใช่ไหม ไม่ได้กลับมาคิดใคร่ครวญว่านี้ทุกข์นี้มรรคนี้กุศลนี้อกุศล ไม่ได้กลับมาใคร่ครวญอย่างนี้จึงจําเป็นจะต้องไปละนิวรณ์แบบนี้ให้ได้ก่อนอะไรประมาณนี่คือคําว่า ทีนี้ในสิ่งที่เรียกว่าอนาคามีนั้นในบุคคลผู้เป็นอนาคามี สังโยชน์ห้าอันเป็นเบื้องบน เบื้องสูงนี้ จําเป็นที่จะต้องละให้ได้ ในตรงนี้มันจะมีรูปราคะกับอรูปราคะ อาจจะใกล้เคียงกับแต่ไม่ใช่ คือไม่ใช่ มันคือความยินดีพอใจในรูปกับในสิ่งที่เรียกว่านามคือไม่ใช่รูป ทีนี้ยินดีพอใจยังไงยินดีพอใจเมื่อรูปให้อะไรได้ อย่างเช่นรูปให้สุขได้ สุขเวทนานี้ สุขยังไง สุขที่เกิดจากการเกิดขึ้น ตั้งอยู่ของมันนี้ ถ้าหากตั้งอยู่ตราบใด จากรูปนะจากรูป สิ่งเหล่านั้นจะเป็นที่น่ายินดี อะไรก็ตามนะทีนี้คืออะไรก็ตาม สิ่งเหล่านั้นจะน่ายินดี อรูปนี้นะอะไรก็ตามที่เกิดจากนาม แล้วให้ผลอันเป็นที่สุขสบายอย่างนี้ อันเป็นที่ตั้งแห่งความยินดี เขาเรียกว่าอรูปราคะ เขาหมายเอาอย่างนี้ อย่างเช่น รูปราคะนี้โดยปกติ ผู้เป็นอนาคามีจะไม่สามารถเสพกามได้อีกต่อไป กามนี้คือกามเมถุนพูดง่ายๆ รูปราคะกับอรูปราคะคืออะไร รูปราคะก็คือสิ่งที่ให้ความสุขจากรูป รูปมันเป็นดินน้ําไฟลมนี่แหละเข้าใจไหม อย่างเช่นอะไร อย่างเช่นรูปที่เกิดขึ้นตั้งอยู่นี้มันให้ความโสมนัสถูกต้องไหม ให้ความน่าปิติ ให้ความน่ายินดี ความยินดีตรงนี้แหละมันทําใจนั้นให้สุขให้สบาย ใจที่สุขสบายตรงนี้นั้นเขาเรียกว่ารูปราคะเข้าใจไหม คือยินดีในใจที่สุขสบายไม่ได้ยินดีในตัวรูป ถ้าพูดง่ายๆอย่างเช่น เรามองเห็นเนื้อหนังพระพุทธเจ้าพระองค์มีผิวพรรณผ่องใสเปล่งปลั่งเป็นที่น่ายินดี อนาคามีผลจะไปยินดีในส่วนที่ทําให้เกิดความยินดีใจ อย่างเช่นทําให้ตัวเองรู้สึกปลาบปลื้มยินดีใจที่พระองค์มีเนื้อหนังผิวพรรณผ่องใสอย่างนี้นะ รูปของพระองค์นั้นเป็นที่ตั้งเพื่อให้เกิดความปลาบปลื้ม โสมนัส ความปลาบปลื้มความโสมมนัสนั้นของอนาคามี เขาเรียกว่ารูปราคะ คือไปยินดีในความโสมนัส ยินดีในความปลาบปลื้ม อันความปลาบปลื้น อันความโสมนัส อันความเบิกบานใจของตัวเองนั้นเกิดจากรูปของพระพุทธเจ้าคือรูปอันเป็นดิน น้ําไฟลมนี่แหละ คือร่างกายอย่างนี้ อย่างนี้รูปราคะ เราเจอกันนั้นเราเจอกันหรือว่าอนาคามีบุคคลผู้ยินดี อย่างเช่นมีความสงบใจ ถามว่าความสงบไปเกิดจากอะไร หากความสงบใจเหล่านั้นเกิดจากรูป ยินดีในความสงบใจไม่ได้ยินดีในรูป แต่รูปให้ความสงบใจ จะเรียกว่ารูปราคะ อรูปราคะทีนี้อย่างเช่นเรามีเวทนา สัญญา สังขาร วิญญาณอันเป็นนามธรรม นามธรรมเหล่านี้ให้สิ่งอื่นแม้ทุกขเวทนา นามธรรมให้ทุกขเวทนา แต่เมื่อทุกขเวทนาอันเป็นที่ตั้ง ทําให้เกิดการใคร่ควรพิจารณาไปในทุกขเวทนา แล้วปรากฏเป็นปีติ เป็นสุข เป็นเอกคตาจิต เป็นปัสสัทธิ เป็นสติขึ้นมา ส่วนเหล่านั้นที่เกิดจากการกําหนดรู้นาม นามขันธ์ที่ชื่อว่าทุกขเวทนา ทําให้เกิดความยินดี  ตรงนี้เขาเรียกว่าอรูปราคะ เข้าใจไหมไม่ได้ยินดีตรงทุกขเวทนา สุขเวทนาเหมือนกันไม่ได้ยินดีตรงสุขเวทนา แต่สุขเวทนานั้นให้อะไร อย่างเช่น ให้ธรรมที่ชื่อว่านิโรธอย่างนี้ อย่างเช่นให้ธรรมที่ชื่อว่าความปราศจากตัณหา อย่างเช่นให้ธรรมที่ชื่อว่ามรรค ในส่วนของมรรค ในส่วนของ วิราคะธรรม ในส่วนของความปราศจากตัณหาที่เกิดจากนามธรรมเหล่านั้นเขาเรียกว่าอรูปราคะ ไม่ได้เกี่ยวกับขันธ์แล้วแต่สิ่งที่เรียกว่าขันธ์นั้นมันให้ มันให้อะไรอย่างนี้ เขาเรียกว่ารูปราคะกับปรูปราคะ"

# %%
text3 = "ตถาคต จะเอาตามศัพท์เลยก็คือ คำว่าตถาเนี่ยมันเป็นประโยคที่เค้าเรียกประโยคคู่ แต่มาตัวเดียว ตถามาตัวเดียวขอให้เข้าใจว่ามันมีคำว่ายถาด้วย คือยถากับตถาเนี่ยมันเป็นประโยคที่ต้องไปคู่กัน แม้มาตัวเดียวก็ต้องมีอีกตัวนึงตามมาด้วย มันเป็นการอมความของบทบาลีที่คนที่เรียนบาลีเขาจะรู้ดี ตถาคตก็คือตถาคตะ ก็ต้องมีคำว่ายถาคตะ เค้าเรียกว่ามาอย่างไรก็ไปอย่างนั้น อย่างนี้ในความหมายนะ คือผู้มาอย่างไรก็ไปอย่างนั้น คือผู้มาตามความเป็นจริงก็ไปตามความเป็นจริง ผู้อยู่ตามความเป็นจริง ผู้เป็นตามความเป็นจริง ผู้เป็นไปอย่างนั้นตถาคตะ คำว่ามาอย่างไรไปอย่างนั้น เป็นไปอย่างนั้น เป็นไปอย่างนั้นแหละ สำนวนไทยจะว่ายังไงดี จะใช้แทนศัพท์ในสำนวนไทยว่าอย่างไรดี ก็คือท่านผู้ที่มีความเป็นอยู่อย่างไรก็อยู่แบบนั้น คำว่าอยู่แบบใดก็แบบนั้น ก็คืออยู่ด้วยความเป็นสมณะ สมณะอยู่แบบใดท่านก็อยู่แบบนั้น ความเป็นพุทธเจ้าอยู่แบบใดก็อยู่แบบนั้น ความเป็นนักบวชอยู่แบบใดก็อยู่แบบนั้น คืออยู่ด้วยความเป็นอยู่ที่อยู่ในทุกได้ทุกสภาพการพูดง่ายๆ ตถาคตเนี่ย คือผู้อยู่โดยตามความเป็นจริงก็ได้ อยู่ตามความเป็นจริงไม่หลงโลก อยู่กับความเป็นจริงของโลก พระอาจารย์ก็จะได้ยุติการตอบไลฟ์ ถือว่าขอคำถามนี้เป็นไลฟ์คำถามสุดท้าย ส่วนคำถามนอกนี้แอดมินช่วย Save ไว้ด้วยเพื่อที่จะไปตอบในวันต่อไป"

# %%
text4 = "ปัญญาเกิดจากการเรียนรู้และเข้าใจสิ่งที่เป็นเหตุและผล คําว่าเหตุและผลหมายถึงว่าทุกอย่างมีเหตุแล้วนํามาซึ่งผล คําว่าเหตุและผลมันไม่ได้หมายถึงการอธิบายถึงเหตุผลบางอย่างในการที่เราจะทําสิ่งนั้นสิ่งนี้ มีเหตุผลอะไรแบบไหนอันนั้นไม่ใช่ลักษณะเหตุผล แค่ว่าเป็นการอธิบายแจกแจงวิธีการที่เราจะกระทําเหตุผลในทุกอย่างก็คือให้เข้าใจว่ามันมีเหตุมันจึงมีผลพอมีเหตุอย่างนี้จึงมีผลอย่างนี้เหตุแห่งความทุกข์เราทําผลแห่งความทุกข์ก็เกิดขึ้น เหตุแห่งความสุขที่เราทําผลแห่งความสุขก็เกิดขึ้นเหตุแห่งการไปสู่ความดับทุกข์ผลแห่งความดับทุกข์ก็เกิดขึ้นเมื่อปัญญาที่รู้เหตุรู้ผลตามความเป็นจริงอย่างนี้ปัญญาชนิดนี้เป็นปัญญาที่พระองค์สรรเสริญมากเพราะเป็นปัญญาที่รู้ต้นสายปลายเหตุของเรื่องราวอย่างถูกต้อง ฉะนั้นปัญญามันจะก่อเกิดจากการที่เราไปเรียนรู้เหตุและผลในแต่ละอันเราจะได้เข้าใจเอาคําว่า ปาณาติปาตาเวรมณี มันมีเหตุผลอะไรที่เราจะต้องไปสมาทานศีลข้อนี้หรือไปงดเว้นจากศีลข้อนี้มันมีเหตุตรงที่ว่าพระองค์บอกว่าบุคคลผู้ฆ่าสัตว์ลักทรัพย์ ผู้ฆ่าสัตว์ทําลายชีวิตสัตว์ลงไปให้ตกลงไปเมื่อเกิดอีกเขาจะได้รับโทษจากการที่มีอายุสั้นในแต่ละด้านในความเป็นอยู่ของชีวิตให้ชีวิตนั้นลําบากหรือ ถูกตัดลอนให้ตัดชีวิตออกไปเหมือนกันกับกรรมที่เราทํา นี่คือเหตุและนํามาซึ่งผลอย่างนี้ มันมีเหตุมีผลอย่างนี้มันขึ้นอยู่กับว่าเมื่อเรารู้เหตุรู้ผล ปัญญาเราจะเข้าไปตัดสินที่จะเลือกในการที่จะงดเว้น ศีลบทข้อนี้หรือเปล่า ฉะนั้นการรักษาสิกขาบทหรือรักษาศีลที่จะเป็นศีลจริงๆ ต้องเป็นการรักษาศีลผ่านปัญญาไม่ใช่กลัวว่าจะตกนรกกลัวว่าเราจะมีโทษอะไรต่างๆจากสิ่งเหล่านี้การกลัวด้วยรักษาศีลด้วยความกลัวพระองค์บอกว่าปัญญาไม่เกิดไม่มีปัญญา "

# %%
text5 = "บุญในทางพระพุทธศาสนาเรากล่าวสรรเสริญบุญที่เกิดจากการมีปัญญาที่รู้แจ้งในสภาพธรรม ปัญญาที่รู้แจ้งในสภาพธรรมพระองค์กล่าวลำดับบุญไว้ว่าบุคคลผู้ทำบุญในระดับชั้นของวัตถุทานก็คือสูงสุดก็คือวิหารทาน ต่อจากวิหารก็เป็นอภัยทาน ต่อจากอภัยทานนั้นก็เป็นการรู้เห็นทำตามความเป็นจริงจะเป็นบุญสูงสุดต่อจากการรู้เห็นธรรมตามเป็นจริงก็จะก้าวเข้าไปสู่ความเป็นโสดาบันจากโสดาบันก็จะก้าวเข้าไปสู่ความเป็นสกิทาคามีอนาคามีและอรหันต์ บุญนอกเหนือจากการเข้าถึงความเป็นอรหันต์แล้วมันก็สิ้นสุดอยู่ที่นั่นบุญก็จะไปจบอยู่ที่นั่นไม่ไม่เพิ่มพูนไปกว่านี้อีกแล้ว ฉะนั้นบุญที่เกิดจากการทำสมาธิเป็นเพียงแค่บุญยังไม่ได้มากพอหรือว่าสูงสุดอย่างที่เขากล่าวกัน ดังที่พระองค์ตรัสไว้ว่าการให้ทานกับภิกษุหรือสมณะพราหมณ์ที่ได้ฌานและสมาธิจะได้ผลบุญเกิดขึ้นแสนโกรธกับก็คือถ้าให้ทานน้ำหนึ่งแก้วน้ำหนึ่งแก้วที่เราให้ทานไปกับบุคคลผู้มีฌานสมาธิแบบฌานสูงสุดแล้วก็สมาธิชั้นสูงสุดในระดับสุดจะได้เกิดผลบุญแสนโกรธ อันแสนโกรธอย่างที่จะเกิดขึ้นแต่ให้ทานกับบุคคลผู้นับถือพระรัตนตรัยจะให้ผลบุญนั้นประมาณไม่ได้ บทบาลีใช้คําว่าอัปปเมยังไม่สามารถประเมินบุญนั้นได้คือมากกว่าให้ทานกับบุคคลผู้ทําสมาธิอันนี้คือขอบเขตหรือปริมาณบุญจากการที่พระองค์ลำดับไว้ฉะนั้นบุญที่เกิดจากการทำสมาธิไม่ได้สูงสุดอย่างที่เราเข้าใจ สมาธิยังไม่สามารถทำคนออกจากวัฏฏะได้แต่พระพุทธเจ้า พระองค์เป็นผู้สิ้นกิเลสแล้วแล้วก็สามารถออกจากวัฏฏะได้ ธรรมะของพระองค์ที่พระองค์ตรัสสอนเป็นธรรมะที่นําพาคนออกจากวัฏฏะพระสงฆ์สาวกของพระสัมมาสัมพุทธเจ้าผู้สิ้นอาสวะกิเลสแล้วเขาเป็นผู้หมดจดบริสุทธิ์ไม่มีมลทินด้วยกิเลสแล้วก็สามารถนคนออกจากได้ โดยลำพังของตัวสมาธิเองไม่ได้สามารถนําพาคนออกจากวัฏฏะ ฤาษีดาบสที่เขาสมณธรรมที่เขาทำฌานสมาบัติกันสูงสุดไปได้ที่พรหมโลกแต่บุคคลผู้นับถือพระรัตนตรัยจะออกจากวัฏฏะในแสนกัปสุดท้าย"

# %%
documents = Document(doc_id="doc1", text=text2),

# %%
#สร้าง index สำหรับการค้นหาข้อมูลจาก ผลลัพธ์จาก query
index = ListIndex.from_documents(documents, service_context=service_context)

# %%
print(index)
# Out:
# <llama_index.core.indices.list.base.SummaryIndex object at 0x000001CDA25EF2C0>

# %% [markdown]
# #### กำหนด Prompt pipeline สำหรับ RAG
#
# Default สำหรับ Llamaindex จะเป็นการ "refine" ซึ่ง refine จะเป็นขั้นตอนการทำงาน 2 ขั้นตอนต่อกัน
# 1. Question and Answer เพื่อให้ LLM ที่กำหนดไว้ใน Service_context ตอบคำถาม
# 2. Refine เพื่อให้คำตอบที่ได้ออกมานั้นสวยงามมากยิ่งขึ้น

# %%
#กำหนด Prompt pipeline สำหรับ RAG
response_synthesizer = get_response_synthesizer(
      response_mode="simple_summarize",service_context=service_context
)

# %%
#สร้าง Query engine จาก index ที่เราได้สร้างจาก ผลลัพธ์จาก Query และเปลี่ยน Response ให้ทำงานแค่ 1 ขั้นตอน
query_engine = index.as_query_engine(
    response_synthesizer=response_synthesizer,
    service_context=service_context,
)

#ค้นหาผลลัพธ์จาก RAG
result = query_engine.query("<summarize in thai>")
print(documents[0].text)
print("result :",result)
# Out:
# กามฉันทะหรอ มีกามสองอย่างที่เรียกว่าสังโยชน์ของบุคคลผู้เป็นอนาคามีจําเป็นต้องละก็คือรูปราคะกับอรูปราคะ ถ้าจะกล่าวถึงความเป็นกามฉันทะ กล่าวได้ไหม กามฉันทะเป็นอย่างนี้ ความยินดีพอใจรักใคร่ในอย่างใดอย่างหนึ่งอย่างเช่นในรูป ในเสียง ในกลิ่น ในรส ในภาพอย่างนี้ ความยินดีพอใจ จนกระทั่งไม่สามารถผละออกไป คือไม่สามารถวางใจ ไม่สามารถผละออกไปคิดใคร่ครวญอยู่ตลอดเวลา แสวงหาอยู่ตลอดเวลาอย่างนี้ คล้อยไปตามอยู่ตลอดเวลา เขาเรียกว่ากามฉันทะ กามฉันทะตรงนี้จึงจัดอยู่ในความเป็นนิวรณ์ ถามว่าทําไมพอมีการมาฉันทะแล้วไม่สามารถประพฤติปฏิบัติธรรมไปได้ พอจะกล่าวก็ต้องละนิวรณ์ก่อนใช่ไหม นิวรณ์ธรรมนั้นต้องเอาออกไปก่อน ทําให้จิตนี้อ่อนควรแก่การงาน เพราะกามฉันทะมันจะดึงจิตนั้นให้ไปหากามอยู่เรื่อยๆ ถามว่าการคิดการใคร่ครวญมันจะคิดยังไงตอนนั้นก็คิดว่าตรงไหนจะเสพเสวยอะไรยังไงมีรูปมีเสียงมีกลิ่นมีรสใช่ไหม ไม่ได้กลับมาคิดใคร่ครวญว่านี้ทุกข์นี้มรรคนี้กุศลนี้อกุศล ไม่ได้กลับมาใคร่ครวญอย่างนี้จึงจําเป็นจะต้องไปละนิวรณ์แบบนี้ให้ได้ก่อนอะไรประมาณนี่คือคําว่ากามฉันทะ ทีนี้ในสิ่งที่เรียกว่าอนาคามีนั้นในบุคคลผู้เป็นอนาคามี สังโยชน์ห้าอันเป็นเบื้องบน เบื้องสูงนี้ จําเป็นที่จะต้องละให้ได้ ในตรงนี้มันจะมีรูปราคะกับอรูปราคะ อาจจะใกล้เคียงกับกามฉันทะแต่ไม่ใช่ คือไม่ใช่กามฉันทะ มันคือความยินดีพอใจในรูปกับในสิ่งที่เรียกว่านามคือไม่ใช่รูป ทีนี้ยินดีพอใจยังไงยินดีพอใจเมื่อรูปให้อะไรได้ อย่างเช่นรูปให้สุขได้ สุขเวทนานี้ สุขยังไง สุขที่เกิดจากการเกิดขึ้น ตั้งอยู่ของมันนี้ ถ้าหากตั้งอยู่ตราบใด จากรูปนะจากรูป สิ่งเหล่านั้นจะเป็นที่น่ายินดี อะไรก็ตามนะทีนี้คืออะไรก็ตาม สิ่งเหล่านั้นจะน่ายินดี อรูปนี้นะอะไรก็ตามที่เกิดจากนาม แล้วให้ผลอันเป็นที่สุขสบายอย่างนี้ อันเป็นที่ตั้งแห่งความยินดี เขาเรียกว่าอรูปราคะ เขาหมายเอาอย่างนี้ อย่างเช่น รูปราคะนี้โดยปกติ ผู้เป็นอนาคามีจะไม่สามารถเสพกามได้อีกต่อไป กามนี้คือกามเมถุนพูดง่ายๆ รูปราคะกับอรูปราคะคืออะไร รูปราคะก็คือสิ่งที่ให้ความสุขจากรูป รูปมันเป็นดินน้ําไฟลมนี่แหละเข้าใจไหม อย่างเช่นอะไร อย่างเช่นรูปที่เกิดขึ้นตั้งอยู่นี้มันให้ความโสมนัสถูกต้องไหม ให้ความน่าปิติ ให้ความน่ายินดี ความยินดีตรงนี้แหละมันทําใจนั้นให้สุขให้สบาย ใจที่สุขสบายตรงนี้นั้นเขาเรียกว่ารูปราคะเข้าใจไหม คือยินดีในใจที่สุขสบายไม่ได้ยินดีในตัวรูป ถ้าพูดง่ายๆอย่างเช่น เรามองเห็นเนื้อหนังพระพุทธเจ้าพระองค์มีผิวพรรณผ่องใสเปล่งปลั่งเป็นที่น่ายินดี อนาคามีผลจะไปยินดีในส่วนที่ทําให้เกิดความยินดีใจ อย่างเช่นทําให้ตัวเองรู้สึกปลาบปลื้มยินดีใจที่พระองค์มีเนื้อหนังผิวพรรณผ่องใสอย่างนี้นะ รูปของพระองค์นั้นเป็นที่ตั้งเพื่อให้เกิดความปลาบปลื้ม โสมนัส ความปลาบปลื้มความโสมมนัสนั้นของอนาคามี เขาเรียกว่ารูปราคะ คือไปยินดีในความโสมนัส ยินดีในความปลาบปลื้ม อันความปลาบปลื้น อันความโสมนัส อันความเบิกบานใจของตัวเองนั้นเกิดจากรูปของพระพุทธเจ้าคือรูปอันเป็นดิน น้ําไฟลมนี่แหละ คือร่างกายอย่างนี้ อย่างนี้รูปราคะ เราเจอกันนั้นเราเจอกันหรือว่าอนาคามีบุคคลผู้ยินดี อย่างเช่นมีความสงบใจ ถามว่าความสงบไปเกิดจากอะไร หากความสงบใจเหล่านั้นเกิดจากรูป ยินดีในความสงบใจไม่ได้ยินดีในรูป แต่รูปให้ความสงบใจ จะเรียกว่ารูปราคะ อรูปราคะทีนี้อย่างเช่นเรามีเวทนา สัญญา สังขาร วิญญาณอันเป็นนามธรรม นามธรรมเหล่านี้ให้สิ่งอื่นแม้ทุกขเวทนา นามธรรมให้ทุกขเวทนา แต่เมื่อทุกขเวทนาอันเป็นที่ตั้ง ทําให้เกิดการใคร่ควรพิจารณาไปในทุกขเวทนา แล้วปรากฏเป็นปีติ เป็นสุข เป็นเอกคตาจิต เป็นปัสสัทธิ เป็นสติขึ้นมา ส่วนเหล่านั้นที่เกิดจากการกําหนดรู้นาม นามขันธ์ที่ชื่อว่าทุกขเวทนา ทําให้เกิดความยินดี  ตรงนี้เขาเรียกว่าอรูปราคะ เข้าใจไหมไม่ได้ยินดีตรงทุกขเวทนา สุขเวทนาเหมือนกันไม่ได้ยินดีตรงสุขเวทนา แต่สุขเวทนานั้นให้อะไร อย่างเช่น ให้ธรรมที่ชื่อว่านิโรธอย่างนี้ อย่างเช่นให้ธรรมที่ชื่อว่าความปราศจากตัณหา อย่างเช่นให้ธรรมที่ชื่อว่ามรรค ในส่วนของมรรค ในส่วนของ วิราคะธรรม ในส่วนของความปราศจากตัณหาที่เกิดจากนามธรรมเหล่านั้นเขาเรียกว่าอรูปราคะ ไม่ได้เกี่ยวกับขันธ์แล้วแต่สิ่งที่เรียกว่าขันธ์นั้นมันให้ มันให้อะไรอย่างนี้ เขาเรียกว่ารูปราคะกับปรูปราคะ
# result : คำว่า "กามฉันทะ" ในภาษาไทยหมายถึงความหลงใหลหรือความหลงไหลอย่างมากในสิ่งใดสิ่งหนึ่งอย่างมากจนไม่สามารถละทิ้งได้ ความยินดีพอใจรักใคร่ในอย่างใดอย่างหนึ่งอย่างเช่นในรูป ในเสียง ในกลิ่น ในรส ในภาพอย่างนี้ ความยินดีพอใจจนไม่สามารถผละออกไป คือไม่สามารถวางใจ ไม่สามารถผละออกไปคิดใคร่ครวญอยู่ตลอดเวลา แสวงหาอยู่ตลอดเวลาอย่างนี้ คล้อยไปตามอยู่ตลอดเวลา เขาเรียกว่ากามฉันทะ กามฉันทะตรงนี้จึงจัดอยู่ในความเป็นนิวรณ์ ถามว่าทำไมพอมีการมาฉันทะแล้วไม่สามารถประพฤติปฏิบัติธรรมได้ พอจะกล่าวก็ต้องละนิวรณ์ก่อนใช่ไหม นิวรณ์ธรรมนั้นต้องเอาออกไปก่อน ทําให้จิตนี้อ่อนควรแก่การงาน เพราะกามฉันทะมันจะดึงจิตนั้นให้ไปหากามอยู่เรื่อยๆ ถามว่าการคิดการใคร่ครวญมันจะคิดยังไงตอนนั้นก็คิดว่าตรงไหนจะเสพเสวยอะไรยังไงมีรูปมีเสียงมีกลิ่นมีรสใช่ไหม ไม่ได้กลับมาคิดใคร่ครวญว่านี้ทุกข์นี้มรรคนี้กุศลนี้อกุศล ไม่ได้กลับมาใคร่ครวญอย่างนี้จึงจําเป็นจะต้องไปละนิวรณ์แบบนี้ให้ได้อะไรประมาณนี่คือคําว่ากามฉันทะ ทีนี้ในสิ่งที่เรียกว่าอนาคามีนั้นในบุคคลผู้เป็นอนาคามี สังโยชน์ห้าอันเป็นเบื้องบน เบื้องสูงนี้จําเป็นที่จะต้องละให้ได้ ในตรงนี้มันจะมีรูปราคะกับอรูปราคะ อาจจะใกล้เคียงกับกามฉันทะแต่ไม่ใช่ คือไม่ใช่กามฉันทะ มันคือความยินดีพอใจในรูปกับในสิ่งที่เรียกว่านามคือไม่ใช่รูปทีนี้ยินดีพอใจยังไงยินดีพอใจเมื่อรูปให้อะไรได้ อย่างเช่นรูปให้สุขได้ สุขเวทนานี้ สุขยังไง สุขที่เกิดจากการเกิดขึ้น ตั้งอยู่ของมันนี้ ถ้าหากตั้งอยู่ตราบใด จากรูปนะจากรูป สิ่งเหล่านั้นจะเป็นที่น่ายินดี อะไรก็ตาม นะทีนี้คืออะไรก็ตาม สิ่งเหล่านั้นจะน่ายินดี อรูปนี้นะอะไรก็ตามที่เกิดจากนาม แล้วให้ผลอันเป็นที่สุขสบายอย่างนี้ อันที่ตั้งแห่งความยินดี เขาเรียกว่าอรูปราคะ เขาหมายเอาอย่าง

# %%
#สร้าง Query engine จาก index ที่เราได้สร้างจาก ผลลัพธ์จาก Query และเปลี่ยน Response ให้ทำงานแค่ 1 ขั้นตอน
query_engine = index.as_query_engine(
    response_synthesizer=response_synthesizer,
    service_context=service_context,
)

#ค้นหาผลลัพธ์จาก RAG
result = query_engine.query("สรุปบทความอย่างละเอียด 1 ย่อหน้า")
print(documents[0].text)
print("result :",result)
# Out:
# กามฉันทะหรอ มีกามสองอย่างที่เรียกว่าสังโยชน์ของบุคคลผู้เป็นอนาคามีจําเป็นต้องละก็คือรูปราคะกับอรูปราคะ ถ้าจะกล่าวถึงความเป็นกามฉันทะ กล่าวได้ไหม กามฉันทะเป็นอย่างนี้ ความยินดีพอใจรักใคร่ในอย่างใดอย่างหนึ่งอย่างเช่นในรูป ในเสียง ในกลิ่น ในรส ในภาพอย่างนี้ ความยินดีพอใจ จนกระทั่งไม่สามารถผละออกไป คือไม่สามารถวางใจ ไม่สามารถผละออกไปคิดใคร่ครวญอยู่ตลอดเวลา แสวงหาอยู่ตลอดเวลาอย่างนี้ คล้อยไปตามอยู่ตลอดเวลา เขาเรียกว่ากามฉันทะ กามฉันทะตรงนี้จึงจัดอยู่ในความเป็นนิวรณ์ ถามว่าทําไมพอมีการมาฉันทะแล้วไม่สามารถประพฤติปฏิบัติธรรมไปได้ พอจะกล่าวก็ต้องละนิวรณ์ก่อนใช่ไหม นิวรณ์ธรรมนั้นต้องเอาออกไปก่อน ทําให้จิตนี้อ่อนควรแก่การงาน เพราะกามฉันทะมันจะดึงจิตนั้นให้ไปหากามอยู่เรื่อยๆ ถามว่าการคิดการใคร่ครวญมันจะคิดยังไงตอนนั้นก็คิดว่าตรงไหนจะเสพเสวยอะไรยังไงมีรูปมีเสียงมีกลิ่นมีรสใช่ไหม ไม่ได้กลับมาคิดใคร่ครวญว่านี้ทุกข์นี้มรรคนี้กุศลนี้อกุศล ไม่ได้กลับมาใคร่ครวญอย่างนี้จึงจําเป็นจะต้องไปละนิวรณ์แบบนี้ให้ได้ก่อนอะไรประมาณนี่คือคําว่ากามฉันทะ ทีนี้ในสิ่งที่เรียกว่าอนาคามีนั้นในบุคคลผู้เป็นอนาคามี สังโยชน์ห้าอันเป็นเบื้องบน เบื้องสูงนี้ จําเป็นที่จะต้องละให้ได้ ในตรงนี้มันจะมีรูปราคะกับอรูปราคะ อาจจะใกล้เคียงกับกามฉันทะแต่ไม่ใช่ คือไม่ใช่กามฉันทะ มันคือความยินดีพอใจในรูปกับในสิ่งที่เรียกว่านามคือไม่ใช่รูป ทีนี้ยินดีพอใจยังไงยินดีพอใจเมื่อรูปให้อะไรได้ อย่างเช่นรูปให้สุขได้ สุขเวทนานี้ สุขยังไง สุขที่เกิดจากการเกิดขึ้น ตั้งอยู่ของมันนี้ ถ้าหากตั้งอยู่ตราบใด จากรูปนะจากรูป สิ่งเหล่านั้นจะเป็นที่น่ายินดี อะไรก็ตามนะทีนี้คืออะไรก็ตาม สิ่งเหล่านั้นจะน่ายินดี อรูปนี้นะอะไรก็ตามที่เกิดจากนาม แล้วให้ผลอันเป็นที่สุขสบายอย่างนี้ อันเป็นที่ตั้งแห่งความยินดี เขาเรียกว่าอรูปราคะ เขาหมายเอาอย่างนี้ อย่างเช่น รูปราคะนี้โดยปกติ ผู้เป็นอนาคามีจะไม่สามารถเสพกามได้อีกต่อไป กามนี้คือกามเมถุนพูดง่ายๆ รูปราคะกับอรูปราคะคืออะไร รูปราคะก็คือสิ่งที่ให้ความสุขจากรูป รูปมันเป็นดินน้ําไฟลมนี่แหละเข้าใจไหม อย่างเช่นอะไร อย่างเช่นรูปที่เกิดขึ้นตั้งอยู่นี้มันให้ความโสมนัสถูกต้องไหม ให้ความน่าปิติ ให้ความน่ายินดี ความยินดีตรงนี้แหละมันทําใจนั้นให้สุขให้สบาย ใจที่สุขสบายตรงนี้นั้นเขาเรียกว่ารูปราคะเข้าใจไหม คือยินดีในใจที่สุขสบายไม่ได้ยินดีในตัวรูป ถ้าพูดง่ายๆอย่างเช่น เรามองเห็นเนื้อหนังพระพุทธเจ้าพระองค์มีผิวพรรณผ่องใสเปล่งปลั่งเป็นที่น่ายินดี อนาคามีผลจะไปยินดีในส่วนที่ทําให้เกิดความยินดีใจ อย่างเช่นทําให้ตัวเองรู้สึกปลาบปลื้มยินดีใจที่พระองค์มีเนื้อหนังผิวพรรณผ่องใสอย่างนี้นะ รูปของพระองค์นั้นเป็นที่ตั้งเพื่อให้เกิดความปลาบปลื้ม โสมนัส ความปลาบปลื้มความโสมมนัสนั้นของอนาคามี เขาเรียกว่ารูปราคะ คือไปยินดีในความโสมนัส ยินดีในความปลาบปลื้ม อันความปลาบปลื้น อันความโสมนัส อันความเบิกบานใจของตัวเองนั้นเกิดจากรูปของพระพุทธเจ้าคือรูปอันเป็นดิน น้ําไฟลมนี่แหละ คือร่างกายอย่างนี้ อย่างนี้รูปราคะ เราเจอกันนั้นเราเจอกันหรือว่าอนาคามีบุคคลผู้ยินดี อย่างเช่นมีความสงบใจ ถามว่าความสงบไปเกิดจากอะไร หากความสงบใจเหล่านั้นเกิดจากรูป ยินดีในความสงบใจไม่ได้ยินดีในรูป แต่รูปให้ความสงบใจ จะเรียกว่ารูปราคะ อรูปราคะทีนี้อย่างเช่นเรามีเวทนา สัญญา สังขาร วิญญาณอันเป็นนามธรรม นามธรรมเหล่านี้ให้สิ่งอื่นแม้ทุกขเวทนา นามธรรมให้ทุกขเวทนา แต่เมื่อทุกขเวทนาอันเป็นที่ตั้ง ทําให้เกิดการใคร่ควรพิจารณาไปในทุกขเวทนา แล้วปรากฏเป็นปีติ เป็นสุข เป็นเอกคตาจิต เป็นปัสสัทธิ เป็นสติขึ้นมา ส่วนเหล่านั้นที่เกิดจากการกําหนดรู้นาม นามขันธ์ที่ชื่อว่าทุกขเวทนา ทําให้เกิดความยินดี  ตรงนี้เขาเรียกว่าอรูปราคะ เข้าใจไหมไม่ได้ยินดีตรงทุกขเวทนา สุขเวทนาเหมือนกันไม่ได้ยินดีตรงสุขเวทนา แต่สุขเวทนานั้นให้อะไร อย่างเช่น ให้ธรรมที่ชื่อว่านิโรธอย่างนี้ อย่างเช่นให้ธรรมที่ชื่อว่าความปราศจากตัณหา อย่างเช่นให้ธรรมที่ชื่อว่ามรรค ในส่วนของมรรค ในส่วนของ วิราคะธรรม ในส่วนของความปราศจากตัณหาที่เกิดจากนามธรรมเหล่านั้นเขาเรียกว่าอรูปราคะ ไม่ได้เกี่ยวกับขันธ์แล้วแต่สิ่งที่เรียกว่าขันธ์นั้นมันให้ มันให้อะไรอย่างนี้ เขาเรียกว่ารูปราคะกับปรูปราคะ
# result : บทความนี้อธิบายถึงความเป็นนิวรณ์และอนาคามี โดยนิวรณ์เป็นความเป็นนิสัยที่ต้องเอาออกก่อนที่จะปฏิบัติธรรมได้ ในขณะที่อนาคามีมีสี่ส่วนประกอบหลัก ได้แก่ สังทาน, สังคาม, สังคิ, และ สังคิราคะ สังทานคือความยินดีพอใจในรูป สังคามคือความยินดีในนาม สังคิคือความยินดีในรูปราคะ และ สังคิราคะคือความยินดีในอรูปราคะ
#
# ความเป็นนิวรณ์เป็นความเป็นนิสัยที่ต้องเอาออกก่อนที่จะปฏิบัติธรรมได้ ในขณะที่อนาคามีมีสี่ส่วนประกอบหลัก ได้แก่ สังทาน, สังคาม, สังคิ, และ สังคิราคะ สังทานคือความยินดีพอใจในรูป สังคามคือความยินดีในนาม สังคิคือความยินดีในรูปราคะ และ สังคิราคะคือความยินดีในอรูปราคะ
